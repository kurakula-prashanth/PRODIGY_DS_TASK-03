# %% [markdown]
# ## Task 3

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
data = pd.read_csv('bank.csv', delimiter=';')
data
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        4521 non-null   int64
#  1   job        4521 non-null   object
#  2   marital    4521 non-null   object
#  3   education  4521 non-null   object
#  4   default    4521 non-null   object
#  5   balance    4521 non-null   int64
#  6   housing    4521 non-null   object
#  7   loan       4521 non-null   object
#  8   contact    4521 non-null   object
#  9   day        4521 non-null   int64
#  10  month      4521 non-null   object
#  11  duration   4521 non-null   int64
#  12  campaign   4521 non-null   int64
#  13  pdays      4521 non-null   int64
#  14  previous   4521 non-null   int64
#  15  poutcome   4521 non-null   object
#  16  y          4521 non-null   object
# dtypes: int64(7), object(10)
# memory usage: 600.6+ KB

# %% [markdown]
# ## Histogram of Age

# %%
sns.histplot(data=data, x='age', bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Histogram of Balance

# %%
sns.histplot(data=data, x='balance', bins=30, kde=True, color='green')
plt.title('Balance Distribution')
plt.xlabel('Balance')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## Bar Plot of Job Categories

# %%
sns.countplot(data=data, x='job', order=data['job'].value_counts().index, palette='pastel')
plt.xticks(rotation=90)
plt.title('Job Category Distribution')
plt.xlabel('Job')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\91812\AppData\Local\Temp\ipykernel_24748\4136308414.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='job', order=data['job'].value_counts().index, palette='pastel')

# %% [markdown]
# ## Bar Plot of Marital Status

# %%
sns.countplot(data=data, x='marital', order=data['marital'].value_counts().index, palette='Set2')
plt.title('Marital Status Distribution')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\91812\AppData\Local\Temp\ipykernel_24748\3738123378.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='marital', order=data['marital'].value_counts().index, palette='Set2')

# %% [markdown]
# ## Box Plot of Balance by Job

# %%
sns.boxplot(data=data, x='job', y='balance')
plt.xticks(rotation=90)
plt.title('Balance Distribution by Job')
plt.xlabel('Job')
plt.ylabel('Balance')
plt.show()

# %% [markdown]
# ## Box Plot of Age by Marital Status

# %%
sns.boxplot(data=data, x='marital', y='age')
plt.title('Age Distribution by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Pie Chart of Education Levels

# %%
data['education'].value_counts().plot.pie(autopct='%1.1f%%', startangle=90)
plt.title('Education Level Distribution')
plt.ylabel('')
plt.show()

# %% [markdown]
# ## Bar Plot of Subscription Rate by Job

# %%
job_subscription = data.groupby('job')['y'].value_counts(normalize=True).unstack().fillna(0)
job_subscription['yes'].plot(kind='bar' , color='skyblue')
plt.title('Subscription Rate by Job')
plt.xlabel('Job')
plt.ylabel('Subscription Rate')
plt.show()

# %% [markdown]
# ## Bar Plot of Subscription Status (y)

# %%
sns.countplot(data=data, x='y', order=data['y'].value_counts().index, palette='Set2')
plt.title('Subscription Status Distribution')
plt.xlabel('Subscription Status')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\91812\AppData\Local\Temp\ipykernel_24748\1624118034.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='y', order=data['y'].value_counts().index, palette='Set2')

# %% [markdown]
# ## Subscription Status by Marital Status

# %%
sns.countplot(data=data, x='marital', hue='y')
plt.title('Subscription Status by Marital Status')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.legend(title='Subscribed')
plt.show()

# %% [markdown]
# ## Subscription Status by Education Level

# %%
sns.countplot(data=data, x='education', hue='y')
plt.title('Subscription Status by Education Level')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.legend(title='Subscribed')
plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
# Convert categorical variables to dummy variables
data_encoded = pd.get_dummies(data, drop_first=True)

# Compute the correlation matrix
corr = data_encoded.corr()

# Plot the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr, annot=True, cmap='Set3',linewidths=0.2)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.tree import plot_tree

# %% [markdown]
# ## Load and Preprocess the Data

# %%
# Convert categorical variables to dummy variables
data_encoded = pd.get_dummies(data, drop_first=True)

# Define features (X) and target (y)
X = data_encoded.drop('y_yes', axis=1)
y = data_encoded['y_yes']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Train a Decision Tree Classifier

# %%
# Train a decision tree classifier
dt_classifier = DecisionTreeClassifier(criterion='gini',max_depth=5,min_samples_split=10)
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_split=10)

# %% [markdown]
# ## Evaluate the Model

# %%
# Make predictions
y_pred = dt_classifier.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')

# Print classification report
print('Classification Report:')
print(classification_report(y_test, y_pred))

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
# Accuracy: 0.90
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.92      0.97      0.94      1205
#         True       0.56      0.34      0.42       152
#
#     accuracy                           0.90      1357
#    macro avg       0.74      0.65      0.68      1357
# weighted avg       0.88      0.90      0.88      1357

# %% [markdown]
# ## Visualize the Decision Tree

# %%
# Visualize the decision tree
plt.figure(figsize=(30, 10))
plot_tree(dt_classifier, feature_names=X.columns, class_names=['No', 'Yes'], filled=True, rounded=True, fontsize=10)
plt.show()
